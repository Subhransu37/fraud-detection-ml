# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')

# %%
df = pd.read_csv('AIML Dataset.csv')

# %%
df.sample(5)
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 2498807   204  TRANSFER  486815.57   C436272256           0.00
# 2244660   186   CASH_IN    5810.44  C1212298198       49537.00
# 2541051   206   PAYMENT    5927.37  C1947602943       20767.00
# 4667055   330  CASH_OUT   58558.78  C1722438693           0.00
# 3685005   276   CASH_IN   68708.20   C197475579     6434632.98
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2498807            0.00  C1577494959      1081110.53      1567926.09        0
# 2244660        55347.44   C205499142      1197682.44      1191872.00        0
# 2541051        14839.63   M245256659            0.00            0.00        0
# 4667055            0.00    C99354775      3620978.94      3679537.72        0
# 3685005      6503341.17    C40511035      1508796.76      1440088.57        0
#
#          isFlaggedFraud
# 2498807               0
# 2244660               0
# 2541051               0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df['isFlaggedFraud'].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.shape
# Out:
# (6362620, 11)

# %%
df['isFraud'].value_counts()[1] / df.shape[0]
# Out:
# np.float64(0.001290820448180152)

# %%
df['type'].value_counts().plot(kind='bar' , title= 'transcation')
plt .xlabel("transcation type")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
fraud_group = df.groupby('type')['isFraud'].mean().sort_values(ascending=True)
fraud_group.plot(kind = 'bar', color = 'salmon' , title='fraudgroup by the category')
plt.ylabel('isfraud or not ')
plt.xlabel('type of fraud')
plt.show()

# %%
df['amount'].describe().astype('int')
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(np.log1p(df['amount']), kde=True , bins = 48 , color= 'green')
plt.title('TRANSCATION AMOUNT DISTRUBUTION {LOG SCALED}')
plt.xlabel('log transformed amount value ')
plt.show()

# %%
sns.boxplot(data =df[ df['amount'] < 50000  ]  , x = 'isFraud' , y = 'amount')
plt.title("Amount vs Fraud rate ")
plt.show()

# %%
df['balancedorg'] = df['oldbalanceOrg' ] - df['newbalanceOrig']
df['balanceddest'] = df['newbalanceDest'] - df['oldbalanceDest']

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balancedorg', 'balanceddest'],
#       dtype='object')

# %%
(df['balancedorg'] < 0 ).sum().astype('int')
# Out:
# np.int64(1399253)

# %%
(df['balanceddest'] < 0 ) . sum()
# Out:
# np.int64(1238864)

# %%
df.head(2)
# Out:
#    step     type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1  PAYMENT  1864.28  C1666544295        21249.0        19384.72
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
#
#    balancedorg  balanceddest
# 0      9839.64           0.0
# 1      1864.28           0.0

# %%
fraud_step = df[df['isFraud'] == 1 ]['step'].value_counts().sort_index()
plt.plot(fraud_step.index , fraud_step.values , label= 'fraud per step')
plt.xlabel('index ofo the step')
plt .ylabel('value of the step  ')
plt .title('fraud over time ')
plt .grid (True)
plt .show()

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balancedorg', 'balanceddest'],
#       dtype='object')

# %%
top_sender = df['nameOrig'].value_counts().head(10)

# %%
top_sender
# Out:
# nameOrig
# C1677795071    3
# C1999539787    3
# C724452879     3
# C1976208114    3
# C400299098     3
# C1784010646    3
# C1530544995    3
# C1065307291    3
# C545315117     3
# C1902386530    3
# Name: count, dtype: int64

# %%
top_receivers = df['nameDest'].value_counts().head(10)
top_receivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C1789550256     99
# C451111351      99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_user = df[df['isFraud'] == 1 ]['nameOrig'].value_counts().head(10)

# %%
fraud_user
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
fraud_type = df[df['type'] .isin(['TRANSFER' , 'CASH_OUT'])]

# %%
fraud_type["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
fraud_type
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data = fraud_type , x = "type" , hue = 'isFraud' , palette = 'Set2')
plt.title('fraud type distribution')
plt.xlabel('type of fraud')
plt.ylabel('count')
plt.show()

# %%
corr =df[['amount' , 'oldbalanceOrg' , 'newbalanceOrig' , 'oldbalanceDest' , 'newbalanceDest' , 'isFraud']].corr()

# %%
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr , annot = True , cmap = 'coolwarm')
plt.title('correlation between the features')
plt.show()

# %%
zero_after_transfer = df[(df["oldbalanceOrg"] > 0) & (df["newbalanceOrig"] == 0) & (df["type"].isin(["TRANSFER" , "CASH_OUT"]))]

# %%
len(zero_after_transfer)
# Out:
# 1188074

# %%
zero_after_transfer.head()
# Out:
#     step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2      1  TRANSFER     181.00  C1305486145          181.0             0.0
# 3      1  CASH_OUT     181.00   C840083671          181.0             0.0
# 15     1  CASH_OUT  229133.94   C905080434        15325.0             0.0
# 19     1  TRANSFER  215310.30  C1670993182          705.0             0.0
# 24     1  TRANSFER  311685.89  C1984094095        10835.0             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2    C553264065             0.0            0.00        1               0
# 3     C38997010         21182.0            0.00        1               0
# 15   C476402209          5083.0        51513.44        0               0
# 19  C1100439041         22425.0            0.00        0               0
# 24   C932583850          6267.0      2719172.89        0               0
#
#     balancedorg  balanceddest
# 2         181.0          0.00
# ...

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report , confusion_matrix , accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.head(
)
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balancedorg  balanceddest
# 0      9839.64           0.0
# 1      1864.28           0.0
# ...

# %%
df.drop(['nameOrig' , 'nameDest' , 'isFlaggedFraud'] ,errors= 'ignore' ,axis = 1 , inplace = True)

# %%
x_train , x_test , y_train , y_test = train_test_split(df.drop('isFraud' , axis = 1) , df['isFraud'] , test_size = 0.3 , random_state = 42 , stratify= df['isFraud'])

# %%
categorical_features = ['type']
numerical_features = ['oldbalanceOrg' , 'newbalanceOrig' , 'oldbalanceDest' , 'newbalanceDest' , 'amount']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(), categorical_features)
    ],
    remainder='drop' 
)

# %%
Pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", LogisticRegression(class_weight='balanced', max_iter=1000))
])

# %%
Pipeline.fit(x_train , y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest',
#                                                    'amount']),
#                                                  ('cat', OneHotEncoder(),
#                                                   ['type'])])),
#                 ('classifier',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = Pipeline.predict(x_test)

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97   1270904
#            1       0.02      0.94      0.04      1620
#
#     accuracy                           0.95   1272524
#    macro avg       0.51      0.94      0.51   1272524
# weighted avg       1.00      0.95      0.97   1272524

# %%
confusion_matrix(y_test , y_pred)
# Out:
# array([[1202458,   68446],
#        [    102,    1518]])

# %%
Pipeline.score(x_test , y_test)* 100
# Out:
# 94.61322536942329

# %%
import joblib

joblib.dump(Pipeline , 'fraud_detection_model.pkl')
# Out:
# ['fraud_detection_model.pkl']
